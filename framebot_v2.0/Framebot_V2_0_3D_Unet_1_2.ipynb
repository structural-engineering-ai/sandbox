# %%
# !pip install segmentation-models-3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation-models-3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-3D) (2.8.2+zzzcolab20220527125636)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.0 MB/s
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.5 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (1.21.6)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.26.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.47.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.14.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (14.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (4.1.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.5.3)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation-models-3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation-models-3D) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation-models-3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import tensorflow as tf
import numpy as np
import keras.backend as K
import segmentation_models_3D as sm

from matplotlib import pyplot as plt
from IPython import display
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import load_model
from keras.metrics import MeanIoU
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# Data

# %%
# get data files
train_x = np.load('/content/drive/MyDrive/framebot_V2/data/train_input.npy', allow_pickle=True)
train_y = np.load('/content/drive/MyDrive/framebot_V2/data/train_label.npy', allow_pickle=True)

val_x = np.load('/content/drive/MyDrive/framebot_V2/data/val_input.npy', allow_pickle=True)
val_y = np.load('/content/drive/MyDrive/framebot_V2/data/val_label.npy', allow_pickle=True)

# %%
# add channel for input
train_x = train_x.reshape(train_x.shape[0], 32, 32, 32, 1)
val_x = val_x.reshape(val_x.shape[0], 32, 32, 32, 1)

# %%
# move axis for labels
train_y = np.moveaxis(train_y, 1, -1)
val_y = np.moveaxis(val_y, 1, -1)

# %%
# Hyper parameters
AUTO = tf.data.experimental.AUTOTUNE

BATCH_SIZE = 8
BUFFER_SIZE = 12600

STEPS_PER_EPOCH = len(train_x) // BATCH_SIZE
VALID_STEPS = len(val_x) // BATCH_SIZE

train_steps = len(train_x) // BATCH_SIZE

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_x, val_y))
val_dataset = val_dataset.shuffle(BUFFER_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %%
train_dataset.element_spec
# Out:
# (TensorSpec(shape=(None, 32, 32, 32, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 32, 32, 32, 7), dtype=tf.float32, name=None))

# %%
val_dataset.element_spec
# Out:
# (TensorSpec(shape=(None, 32, 32, 32, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 32, 32, 32, 7), dtype=tf.float32, name=None))

# %% [markdown]
# Model

# %%
def get_model():
    inputs = tf.keras.layers.Input((32, 32, 32, 1))
    output_channels = 7


    # Entry block 
    c1 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(inputs)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Activation("relu")(c1)
    c1 = layers.Dropout(0.1)(c1)

    c1 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c1)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Activation("relu")(c1)
    c1 = layers.Dropout(0.1)(c1)

    c1 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c1)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Activation("relu")(c1)
    c1 = layers.Dropout(0.1)(c1)

    c1 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c1)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Activation("relu")(c1)

    p1 = layers.MaxPooling3D(2, strides=2, padding="same")(c1)


    # Downsample block 1
    c2 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(p1)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Activation("relu")(c2)
    c2 = layers.Dropout(0.1)(c2)

    c2 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c2)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Activation("relu")(c2)
    c2 = layers.Dropout(0.1)(c2)

    c2 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c2)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Activation("relu")(c2)
    c2 = layers.Dropout(0.1)(c2)

    c2 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c2)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Activation("relu")(c2)

    p2 = layers.MaxPooling3D(2, strides=2, padding="same")(c2)


    # Downsample block 2
    c3 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(p2)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Activation("relu")(c3)
    c3 = layers.Dropout(0.2)(c3)

    c3 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c3)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Activation("relu")(c3)
    c3 = layers.Dropout(0.2)(c3)

    c3 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c3)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Activation("relu")(c3)
    c3 = layers.Dropout(0.2)(c3)

    c3 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c3)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Activation("relu")(c3)

    p3 = layers.MaxPooling3D(2, strides=2, padding="same")(c3)
    

    # Downsample block 3
    c4 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(p3)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Activation("relu")(c4)
    c4 = layers.Dropout(0.2)(c4)

    c4 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c4)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Activation("relu")(c4)
    c4 = layers.Dropout(0.2)(c4)

    c4 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c4)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Activation("relu")(c4)
    c4 = layers.Dropout(0.2)(c4)

    c4 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c4)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Activation("relu")(c4)

    p4 = layers.MaxPooling3D(2, strides=2, padding="same")(c4)


    # Downsample block 4
    c5 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(p4)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Activation("relu")(c5)
    c5 = layers.Dropout(0.2)(c5)

    c5 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c5)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Activation("relu")(c5)
    c5 = layers.Dropout(0.2)(c5)

    c5 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c5)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Activation("relu")(c5)
    c5 = layers.Dropout(0.2)(c5)

    c5 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c5)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Activation("relu")(c5)

    p5 = layers.MaxPooling3D(2, strides=2, padding="same")(c5)


    # Bottom block
    c6 = layers.Conv3D(1024, 3, kernel_initializer='he_normal', padding="same")(p5)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Activation("relu")(c6)
    c6 = layers.Dropout(0.3)(c6)

    c6 = layers.Conv3D(2048, 3, kernel_initializer='he_normal', padding="same")(c6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Activation("relu")(c6)
    c6 = layers.Dropout(0.3)(c6)

    c6 = layers.Conv3D(2048, 3, kernel_initializer='he_normal', padding="same")(c6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Activation("relu")(c6)
    c6 = layers.Dropout(0.3)(c6)

    c6 = layers.Conv3D(1024, 3, kernel_initializer='he_normal', padding="same")(c6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Activation("relu")(c6)


    # Upsample block 1
    u7 = tf.keras.layers.Conv3DTranspose(512, 2, strides=2, padding="same")(c6)
    u7 = layers.Concatenate()([u7, c5])

    c7 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(u7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Activation("relu")(c7)
    c7 = layers.Dropout(0.2)(c7)

    c7 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Activation("relu")(c7)
    c7 = layers.Dropout(0.2)(c7)

    c7 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Activation("relu")(c7)
    c7 = layers.Dropout(0.2)(c7)

    c7 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Activation("relu")(c7)

    c7 = layers.Conv3D(512, 3, kernel_initializer='he_normal', padding="same")(c7)


    # Upsample block 2
    u8 = tf.keras.layers.Conv3DTranspose(256, 2, strides=2, padding="same")(c7)
    u8 = layers.Concatenate()([u8, c4])

    c8 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(u8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)

    c8 = layers.Conv3D(256, 3, kernel_initializer='he_normal', padding="same")(c8)


    # Upsample block 3
    u9 = tf.keras.layers.Conv3DTranspose(128, 2, strides=2, padding="same")(c8)
    u9 = layers.Concatenate()([u9, c3])

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(u9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)


    # Upsample block 4
    u8 = tf.keras.layers.Conv3DTranspose(64, 2, strides=2, padding="same")(c7)
    u8 = layers.Concatenate()([u8, c4])

    c8 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(u8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Activation("relu")(c8)
    c8 = layers.Dropout(0.2)(c8)

    c8 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c8)
    

    # Upsample block 5
    u9 = tf.keras.layers.Conv3DTranspose(128, 2, strides=2, padding="same")(c8)
    u9 = layers.Concatenate()([u9, c3])

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(u9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)
    c9 = layers.Dropout(0.2)(c9)

    c9 = layers.Conv3D(128, 3, kernel_initializer='he_normal', padding="same")(c9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Activation("relu")(c9)


    # Upsample block 6
    u10 = tf.keras.layers.Conv3DTranspose(64, 2, strides=2, padding="same")(c9)
    u10 = layers.Concatenate()([u10, c2])

    c10 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(u10)
    c10 = layers.BatchNormalization()(c10)
    c10 = layers.Activation("relu")(c10)
    c10 = layers.Dropout(0.2)(c10)

    c10 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c10)
    c10 = layers.BatchNormalization()(c10)
    c10 = layers.Activation("relu")(c10)
    c10 = layers.Dropout(0.2)(c10)

    c10 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c10)
    c10 = layers.BatchNormalization()(c10)
    c10 = layers.Activation("relu")(c10)
    c10 = layers.Dropout(0.2)(c10)

    c10 = layers.Conv3D(64, 3, kernel_initializer='he_normal', padding="same")(c10)
    c10 = layers.BatchNormalization()(c10)
    c10 = layers.Activation("relu")(c10)


    # Upsample block 7
    u11 = tf.keras.layers.Conv3DTranspose(32, 2, strides=2, padding="same")(c10)
    u11 = layers.Concatenate()([u11, c1])

    c11 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(u11)
    c11 = layers.BatchNormalization()(c11)
    c11 = layers.Activation("relu")(c11)
    c11 = layers.Dropout(0.2)(c11)

    c11 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c11)
    c11 = layers.BatchNormalization()(c11)
    c11 = layers.Activation("relu")(c11)
    c11 = layers.Dropout(0.2)(c11)

    c11 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c11)
    c11 = layers.BatchNormalization()(c11)
    c11 = layers.Activation("relu")(c11)
    c11 = layers.Dropout(0.2)(c11)

    c11 = layers.Conv3D(32, 3, kernel_initializer='he_normal', padding="same")(c11)
    c11 = layers.BatchNormalization()(c11)
    c11 = layers.Activation("relu")(c11)
    

    # Add per-pixel classification layer
    outputs = layers.Conv3D(output_channels, 1, activation="softmax")(c11)


    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
tf.keras.backend.clear_session()
# model = get_model()
model = get_model()
# tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 32,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 32, 32, 32,   896         ['input_1[0][0]']
#                                 32)
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32,   128        ['conv3d[0][0]']
#  alization)                     32)
#
#  activation (Activation)        (None, 32, 32, 32,   0           ['batch_normalization[0][0]']
#                                 32)
#
#  dropout (Dropout)              (None, 32, 32, 32,   0           ['activation[0][0]']
#                                 32)
#
#  conv3d_1 (Conv3D)              (None, 32, 32, 32,   27680       ['dropout[0][0]']
#                                 32)
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 32,   128        ['conv3d_1[0][0]']
#  rmalization)                   32)
#
#  activation_1 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_1[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 32, 32, 32,   0           ['activation_1[0][0]']
#                                 32)
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32,   128        ['conv3d_2[0][0]']
#  rmalization)                   32)
#
#  activation_2 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_2[0][0]']
#                                 32)
#
#  dropout_2 (Dropout)            (None, 32, 32, 32,   0           ['activation_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 32, 32, 32,   27680       ['dropout_2[0][0]']
#                                 32)
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 32,   128        ['conv3d_3[0][0]']
#  rmalization)                   32)
#
#  activation_3 (Activation)      (None, 32, 32, 32,   0           ['batch_normalization_3[0][0]']
#                                 32)
#
#  max_pooling3d (MaxPooling3D)   (None, 16, 16, 16,   0           ['activation_3[0][0]']
#                                 32)
#
#  conv3d_4 (Conv3D)              (None, 16, 16, 16,   55360       ['max_pooling3d[0][0]']
#                                 64)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_4[0][0]']
#  rmalization)                   64)
#
#  activation_4 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_4[0][0]']
#                                 64)
#
#  dropout_3 (Dropout)            (None, 16, 16, 16,   0           ['activation_4[0][0]']
#                                 64)
#
#  conv3d_5 (Conv3D)              (None, 16, 16, 16,   110656      ['dropout_3[0][0]']
#                                 64)
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_5[0][0]']
#  rmalization)                   64)
#
#  activation_5 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_5[0][0]']
#                                 64)
#
#  dropout_4 (Dropout)            (None, 16, 16, 16,   0           ['activation_5[0][0]']
#                                 64)
#
#  conv3d_6 (Conv3D)              (None, 16, 16, 16,   110656      ['dropout_4[0][0]']
#                                 64)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_6[0][0]']
#  rmalization)                   64)
#
#  activation_6 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_6[0][0]']
#                                 64)
#
#  dropout_5 (Dropout)            (None, 16, 16, 16,   0           ['activation_6[0][0]']
#                                 64)
#
#  conv3d_7 (Conv3D)              (None, 16, 16, 16,   110656      ['dropout_5[0][0]']
#                                 64)
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 16,   256        ['conv3d_7[0][0]']
#  rmalization)                   64)
#
#  activation_7 (Activation)      (None, 16, 16, 16,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 8, 8, 8, 64)  0          ['activation_7[0][0]']
#
#  conv3d_8 (Conv3D)              (None, 8, 8, 8, 128  221312      ['max_pooling3d_1[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 8, 128  512        ['conv3d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 8, 8, 8, 128  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 8, 8, 8, 128  0           ['activation_8[0][0]']
#                                 )
#
#  conv3d_9 (Conv3D)              (None, 8, 8, 8, 128  442496      ['dropout_6[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 8, 128  512        ['conv3d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 8, 8, 8, 128  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 8, 8, 8, 128  0           ['activation_9[0][0]']
#                                 )
#
#  conv3d_10 (Conv3D)             (None, 8, 8, 8, 128  442496      ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_10[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 8, 8, 8, 128  0           ['activation_10[0][0]']
#                                 )
#
#  conv3d_11 (Conv3D)             (None, 8, 8, 8, 128  442496      ['dropout_8[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_11[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 4, 4, 4, 128  0          ['activation_11[0][0]']
#                                 )
#
#  conv3d_12 (Conv3D)             (None, 4, 4, 4, 256  884992      ['max_pooling3d_2[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 4, 256  1024       ['conv3d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 4, 4, 4, 256  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 4, 4, 4, 256  0           ['activation_12[0][0]']
#                                 )
#
#  conv3d_13 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['dropout_9[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 4, 256  1024       ['conv3d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 4, 4, 4, 256  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 4, 4, 4, 256  0           ['activation_13[0][0]']
#                                 )
#
#  conv3d_14 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['dropout_10[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 4, 256  1024       ['conv3d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 4, 4, 4, 256  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 4, 4, 4, 256  0           ['activation_14[0][0]']
#                                 )
#
#  conv3d_15 (Conv3D)             (None, 4, 4, 4, 256  1769728     ['dropout_11[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 4, 256  1024       ['conv3d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 4, 4, 4, 256  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 2, 2, 2, 256  0          ['activation_15[0][0]']
#                                 )
#
#  conv3d_16 (Conv3D)             (None, 2, 2, 2, 512  3539456     ['max_pooling3d_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 2, 2, 2, 512  2048       ['conv3d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 2, 2, 2, 512  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 2, 2, 2, 512  0           ['activation_16[0][0]']
#                                 )
#
#  conv3d_17 (Conv3D)             (None, 2, 2, 2, 512  7078400     ['dropout_12[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 2, 2, 2, 512  2048       ['conv3d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 2, 2, 2, 512  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 2, 2, 2, 512  0           ['activation_17[0][0]']
#                                 )
#
#  conv3d_18 (Conv3D)             (None, 2, 2, 2, 102  14156800    ['dropout_13[0][0]']
#                                 4)
#
#  batch_normalization_18 (BatchN  (None, 2, 2, 2, 102  4096       ['conv3d_18[0][0]']
#  ormalization)                  4)
#
#  activation_18 (Activation)     (None, 2, 2, 2, 102  0           ['batch_normalization_18[0][0]']
#                                 4)
#
#  dropout_14 (Dropout)           (None, 2, 2, 2, 102  0           ['activation_18[0][0]']
#                                 4)
#
#  conv3d_19 (Conv3D)             (None, 2, 2, 2, 102  28312576    ['dropout_14[0][0]']
#                                 4)
#
#  batch_normalization_19 (BatchN  (None, 2, 2, 2, 102  4096       ['conv3d_19[0][0]']
#  ormalization)                  4)
#
#  activation_19 (Activation)     (None, 2, 2, 2, 102  0           ['batch_normalization_19[0][0]']
#                                 4)
#
#  max_pooling3d_4 (MaxPooling3D)  (None, 1, 1, 1, 102  0          ['activation_19[0][0]']
#                                 4)
#
#  conv3d_20 (Conv3D)             (None, 1, 1, 1, 204  56625152    ['max_pooling3d_4[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 1, 1, 1, 204  8192       ['conv3d_20[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 1, 1, 1, 204  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  dropout_15 (Dropout)           (None, 1, 1, 1, 204  0           ['activation_20[0][0]']
#                                 8)
#
#  conv3d_21 (Conv3D)             (None, 1, 1, 1, 204  113248256   ['dropout_15[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 1, 1, 1, 204  8192       ['conv3d_21[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 1, 1, 1, 204  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  dropout_16 (Dropout)           (None, 1, 1, 1, 204  0           ['activation_21[0][0]']
#                                 8)
#
#  conv3d_22 (Conv3D)             (None, 1, 1, 1, 204  113248256   ['dropout_16[0][0]']
#                                 8)
#
#  batch_normalization_22 (BatchN  (None, 1, 1, 1, 204  8192       ['conv3d_22[0][0]']
#  ormalization)                  8)
#
#  activation_22 (Activation)     (None, 1, 1, 1, 204  0           ['batch_normalization_22[0][0]']
#                                 8)
#
#  dropout_17 (Dropout)           (None, 1, 1, 1, 204  0           ['activation_22[0][0]']
#                                 8)
#
#  conv3d_23 (Conv3D)             (None, 1, 1, 1, 204  113248256   ['dropout_17[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 1, 1, 1, 204  8192       ['conv3d_23[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 1, 1, 1, 204  0           ['batch_normalization_23[0][0]']
#                                 8)
#
#  conv3d_transpose (Conv3DTransp  (None, 2, 2, 2, 102  16778240   ['activation_23[0][0]']
#  ose)                           4)
#
#  concatenate (Concatenate)      (None, 2, 2, 2, 204  0           ['conv3d_transpose[0][0]',
#                                 8)                                'activation_19[0][0]']
#
#  conv3d_24 (Conv3D)             (None, 2, 2, 2, 102  56624128    ['concatenate[0][0]']
#                                 4)
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 2, 102  4096       ['conv3d_24[0][0]']
#  ormalization)                  4)
#
#  activation_24 (Activation)     (None, 2, 2, 2, 102  0           ['batch_normalization_24[0][0]']
#                                 4)
#
#  dropout_18 (Dropout)           (None, 2, 2, 2, 102  0           ['activation_24[0][0]']
#                                 4)
#
#  conv3d_25 (Conv3D)             (None, 2, 2, 2, 102  28312576    ['dropout_18[0][0]']
#                                 4)
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 2, 102  4096       ['conv3d_25[0][0]']
#  ormalization)                  4)
#
#  activation_25 (Activation)     (None, 2, 2, 2, 102  0           ['batch_normalization_25[0][0]']
#                                 4)
#
#  dropout_19 (Dropout)           (None, 2, 2, 2, 102  0           ['activation_25[0][0]']
#                                 4)
#
#  conv3d_26 (Conv3D)             (None, 2, 2, 2, 512  14156288    ['dropout_19[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 2, 512  2048       ['conv3d_26[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 2, 2, 2, 512  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  dropout_20 (Dropout)           (None, 2, 2, 2, 512  0           ['activation_26[0][0]']
#                                 )
#
#  conv3d_27 (Conv3D)             (None, 2, 2, 2, 512  7078400     ['dropout_20[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 2, 512  2048       ['conv3d_27[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 2, 2, 2, 512  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv3d_28 (Conv3D)             (None, 2, 2, 2, 512  7078400     ['activation_27[0][0]']
#                                 )
#
#  conv3d_transpose_3 (Conv3DTran  (None, 4, 4, 4, 64)  262208     ['conv3d_28[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 4, 4, 4, 320  0           ['conv3d_transpose_3[0][0]',
#                                 )                                 'activation_15[0][0]']
#
#  conv3d_38 (Conv3D)             (None, 4, 4, 4, 64)  553024      ['concatenate_3[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 4, 4, 4, 64)  256        ['conv3d_38[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 4, 4, 4, 64)  0           ['batch_normalization_35[0][0]']
#
#  dropout_27 (Dropout)           (None, 4, 4, 4, 64)  0           ['activation_35[0][0]']
#
#  conv3d_39 (Conv3D)             (None, 4, 4, 4, 64)  110656      ['dropout_27[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 4, 4, 4, 64)  256        ['conv3d_39[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 4, 4, 4, 64)  0           ['batch_normalization_36[0][0]']
#
#  dropout_28 (Dropout)           (None, 4, 4, 4, 64)  0           ['activation_36[0][0]']
#
#  conv3d_40 (Conv3D)             (None, 4, 4, 4, 64)  110656      ['dropout_28[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 4, 4, 4, 64)  256        ['conv3d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 4, 4, 4, 64)  0           ['batch_normalization_37[0][0]']
#
#  dropout_29 (Dropout)           (None, 4, 4, 4, 64)  0           ['activation_37[0][0]']
#
#  conv3d_41 (Conv3D)             (None, 4, 4, 4, 64)  110656      ['dropout_29[0][0]']
#
#  conv3d_transpose_4 (Conv3DTran  (None, 8, 8, 8, 128  65664      ['conv3d_41[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 8, 256  0           ['conv3d_transpose_4[0][0]',
#                                 )                                 'activation_11[0][0]']
#
#  conv3d_42 (Conv3D)             (None, 8, 8, 8, 128  884864      ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_42[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  dropout_30 (Dropout)           (None, 8, 8, 8, 128  0           ['activation_38[0][0]']
#                                 )
#
#  conv3d_43 (Conv3D)             (None, 8, 8, 8, 128  442496      ['dropout_30[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_43[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  dropout_31 (Dropout)           (None, 8, 8, 8, 128  0           ['activation_39[0][0]']
#                                 )
#
#  conv3d_44 (Conv3D)             (None, 8, 8, 8, 128  442496      ['dropout_31[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_44[0][0]']
#  ormalization)                  )
#
#  activation_40 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  dropout_32 (Dropout)           (None, 8, 8, 8, 128  0           ['activation_40[0][0]']
#                                 )
#
#  conv3d_45 (Conv3D)             (None, 8, 8, 8, 128  442496      ['dropout_32[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_45[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv3d_transpose_5 (Conv3DTran  (None, 16, 16, 16,   65600      ['activation_41[0][0]']
#  spose)                         64)
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_5[0][0]',
#                                 128)                              'activation_7[0][0]']
#
#  conv3d_46 (Conv3D)             (None, 16, 16, 16,   221248      ['concatenate_5[0][0]']
#                                 64)
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 16,   256        ['conv3d_46[0][0]']
#  ormalization)                  64)
#
#  activation_42 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_42[0][0]']
#                                 64)
#
#  dropout_33 (Dropout)           (None, 16, 16, 16,   0           ['activation_42[0][0]']
#                                 64)
#
#  conv3d_47 (Conv3D)             (None, 16, 16, 16,   110656      ['dropout_33[0][0]']
#                                 64)
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 16,   256        ['conv3d_47[0][0]']
#  ormalization)                  64)
#
#  activation_43 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_43[0][0]']
#                                 64)
#
#  dropout_34 (Dropout)           (None, 16, 16, 16,   0           ['activation_43[0][0]']
#                                 64)
#
#  conv3d_48 (Conv3D)             (None, 16, 16, 16,   110656      ['dropout_34[0][0]']
#                                 64)
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 16,   256        ['conv3d_48[0][0]']
#  ormalization)                  64)
#
#  activation_44 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_44[0][0]']
#                                 64)
#
#  dropout_35 (Dropout)           (None, 16, 16, 16,   0           ['activation_44[0][0]']
#                                 64)
#
#  conv3d_49 (Conv3D)             (None, 16, 16, 16,   110656      ['dropout_35[0][0]']
#                                 64)
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 16,   256        ['conv3d_49[0][0]']
#  ormalization)                  64)
#
#  activation_45 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_45[0][0]']
#                                 64)
#
#  conv3d_transpose_6 (Conv3DTran  (None, 32, 32, 32,   16416      ['activation_45[0][0]']
#  spose)                         32)
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_6[0][0]',
#                                 64)                               'activation_3[0][0]']
#
#  conv3d_50 (Conv3D)             (None, 32, 32, 32,   55328       ['concatenate_6[0][0]']
#                                 32)
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 32,   128        ['conv3d_50[0][0]']
#  ormalization)                  32)
#
#  activation_46 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_46[0][0]']
#                                 32)
#
#  dropout_36 (Dropout)           (None, 32, 32, 32,   0           ['activation_46[0][0]']
#                                 32)
#
#  conv3d_51 (Conv3D)             (None, 32, 32, 32,   27680       ['dropout_36[0][0]']
#                                 32)
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 32,   128        ['conv3d_51[0][0]']
#  ormalization)                  32)
#
#  activation_47 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_47[0][0]']
#                                 32)
#
#  dropout_37 (Dropout)           (None, 32, 32, 32,   0           ['activation_47[0][0]']
#                                 32)
#
#  conv3d_52 (Conv3D)             (None, 32, 32, 32,   27680       ['dropout_37[0][0]']
#                                 32)
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 32,   128        ['conv3d_52[0][0]']
#  ormalization)                  32)
#
#  activation_48 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_48[0][0]']
#                                 32)
#
#  dropout_38 (Dropout)           (None, 32, 32, 32,   0           ['activation_48[0][0]']
#                                 32)
#
#  conv3d_53 (Conv3D)             (None, 32, 32, 32,   27680       ['dropout_38[0][0]']
#                                 32)
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 32,   128        ['conv3d_53[0][0]']
#  ormalization)                  32)
#
#  activation_49 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_49[0][0]']
#                                 32)
#
#  conv3d_54 (Conv3D)             (None, 32, 32, 32,   231         ['activation_49[0][0]']
#                                 7)
#
# ==================================================================================================
# Total params: 591,967,847
# Trainable params: 591,933,159
# Non-trainable params: 34,688
# __________________________________________________________________________________________________

# %% [markdown]
# Train model

# %%
# model location
# small model
save_model_path = "/content/drive/MyDrive/framebot_V2/model/framebot_v2.0_3d_Unet_1.2.h5"

# %%
checkpoint_filepath = '/content/drive/MyDrive/framebot_V2/checkpoints/'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_iou_score',
    mode='max',
    save_best_only=True)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
dice_loss = sm.losses.DiceLoss() 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

loss = sm.losses.categorical_focal_dice_loss

metrics = [sm.metrics.IOUScore(threshold=0.5)]
# metrics = ['accuracy']

# %%
# Load model for retraining
# model = load_model(save_model_path, custom_objects={'focal_loss': focal_loss})

# Load model for testing - ignore loss error
# model = load_model(save_model_path, compile=False)

# %%
# Compile model

###HIDE THIS IF LOADING MODEL FOR TESTING OR USE

model.compile(
    loss = loss,
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=metrics
    )

# %%
EPOCHS = 1000

# %%
history = model.fit(
    train_dataset,
    validation_data = val_dataset,
    epochs = EPOCHS,
    shuffle = True,
    verbose = 2,
    callbacks=[model_checkpoint_callback, early_stopping]
)

# %%
# save model
model.save(save_model_path)

# %%
###
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IOU')
plt.plot(epochs, val_acc, 'r', label='Validation IOU')
plt.title('Training and validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate Model

# %%
test_x = np.load('/content/drive/MyDrive/framebot_V2/data/test_input.npy', allow_pickle=True)
test_y = np.load('/content/drive/MyDrive/framebot_V2/data/test_label.npy', allow_pickle=True)

# %%
# add channel for input
test_x = test_x.reshape(test_x.shape[0], 32, 32, 32, 1)

# move axis for labels
test_y = np.moveaxis(test_y, 1, -1)

# %%
# Hyper parameters
AUTO = tf.data.experimental.AUTOTUNE

BATCH_SIZE = 8
BUFFER_SIZE = 12600

STEPS_PER_EPOCH = len(test_x) // BATCH_SIZE
VALID_STEPS = len(test_x) // BATCH_SIZE

train_steps = len(test_x) // BATCH_SIZE

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y))
test_dataset = test_dataset.shuffle(BUFFER_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
test_dataset.element_spec
# Out:
# (TensorSpec(shape=(None, 32, 32, 32, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 32, 32, 32, 7), dtype=tf.float32, name=None))

# %%
model.evaluate(test_dataset)
# Out:
# 125/125 [==============================] - 26s 87ms/step - loss: 0.0711 - iou_score: 0.8893
# [0.07107943296432495, 0.8893222212791443]
